# %%
import pandas as pd

df = pd.read_csv('movies.csv')
df.tail(3)
df.columns
df['director']
# Out:
# 0          Frank Darabont
# 1    Francis Ford Coppola
# 2       Christopher Nolan
# 3       Quentin Tarantino
# 4       Christopher Nolan
# Name: director, dtype: str
