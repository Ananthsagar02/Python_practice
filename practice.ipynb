# %%
a = "ananth"

# %%
a
# Out:
# 'ananth'

# %%
type(a)
# Out:
# str

# %%
b = 123;
type(b)
# Out:
# int

# %%
4jcb =100
4jcp
# Out:
#   Cell In[9], line 1
#     4jcb =100
#      ^
# SyntaxError: invalid imaginary literal

# %%
_pd = 98
_pd
# Out:
# 98

# %%
base = 10
height =7
area = base * height

# %%
area
# Out:
# 70

# %%
3e4
# Out:
# 30000.0

# %%
1e3
# Out:
# 1000.0

# %%
3e4
# Out:
# -30000.0

# %%
food = "120.34"
rent = "100.00"
total = float(food) + float(rent)
total

type(total)
# Out:
# float

# %%
import math 
x = 64
y = math.sqrt(x)
y
# Out:
# 8.0

# %%
first = "Ananth"
first
first[0:4]
first[-3:-1]
r = first.replace("A", "a")
r
# Out:
# 'ananth'

# %%
sp = 'anfanteh'
s = sp.split()
s
# Out:
# ['anfanteh']

# %%
t1 = "The Himalayas are one of the youngest mountain ranges on the planet"
print(f"{t1[:14]} {t1[-12:]}")
# Out:
# The Himalayas  n the planet

# %%
string = "There are 9 planets in the solar system"
print(string.replace("9 planets", "8 planets"))
n = -9 % 2
n
# Out:
# There are 8 planets in the solar system
# 1

# %%
items = ["ananth", "sai", "kumar", "sai", "kumar"]
items.insert(2, "sagar")
items[-1] = "kumarg"
items
# Out:
# ['ananth', 'sai', 'sagar', 'kumar', 'sai', 'kumarg']
